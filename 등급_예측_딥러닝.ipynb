# %%
import pandas as pd
# Out:
# c:\anaconda3\envs\py_397\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\anaconda3\envs\py_397\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\anaconda3\envs\py_397\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_excel('./data/final_all_data.xlsx')
df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        유투버   월    연도     평균 조회수  \
# 0                0             0           0  @Mingokim   8  2022        NaN
# 1                1             1           1  @Mingokim   9  2022        NaN
# 2                2             2           2  @Mingokim  10  2022        NaN
# 3                3             3           3  @Mingokim  11  2022        NaN
# 4                4             4           4  @Mingokim  12  2022        NaN
# ...            ...           ...         ...        ...  ..   ...        ...
# 3206          3206          3206        3206         희주   4  2023   60805.00
# 3207          3207          3207        3207         희주   5  2023  134596.00
# 3208          3208          3208        3208         희주   6  2023   63369.75
# 3209          3209          3209        3209         희주   7  2023   58993.00
# 3210          3210          3210        3210         희주   8  2023   43819.50
#
#       평균 영상 좋아요 수  영상개수     구독자  ...   인지도  성장률  필터링전_총점  필터링전_총_점수(확인용)  \
# 0             NaN     0    1240  ...   0.0  7.5      7.5             7.5
# 1             NaN     0    1240  ...   0.0  5.0      5.0             5.0
# 2             NaN     0    1240  ...   0.0  5.0      5.0             5.0
# 3             NaN     0    1240  ...   0.0  5.0      5.0             5.0
# 4             NaN     0    1230  ...   0.0  0.0      0.0             0.0
# ...           ...   ...     ...  ...   ...  ...      ...             ...
# 3206  1358.962805     3  792000  ...  30.0  5.0     64.0            64.0
# 3207  3008.156527     3  792000  ...  30.0  5.0     65.0            65.0
# 3208  1416.283746     4  794000  ...  30.0  7.5     77.5            77.5
# 3209  1318.465467     4  795000  ...  30.0  7.5     77.5            77.5
# 3210   979.344965     2  794000  ...  30.0  0.0     54.0            54.0
#
#       점수 재조정_창수  점수 재조정_다현  필터링_취합  bool  최종_점수  등급
# 0           7.5        NaN     7.5     1    7.5   E
# 1           7.5        NaN     7.5     1    7.5   E
# 2           7.5        NaN     7.5     1    7.5   E
# 3           4.5        NaN     4.5     1    4.5   F
# 4           4.5        NaN     4.5     1    4.5   F
# ...         ...        ...     ...   ...    ...  ..
# 3206        NaN        NaN     0.0     0   64.0  B+
# 3207        NaN        NaN     0.0     0   65.0  B+
# 3208        NaN        NaN     0.0     0   77.5  A0
# 3209        NaN        NaN     0.0     0   77.5  A0
# 3210        NaN        NaN     0.0     0   54.0  B0
#
# [3211 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', '유투버', '월', '연도',
#        '평균 조회수', '평균 영상 좋아요 수', '영상개수', '구독자', '구독자 성장율', '감성점수', '평균_영상간격',
#        'null_지속', '충성시청자_비율', '구독자점수', '조회수점수', '충성도점수', '구독자 성장율점수', '감성점수점수',
#        '평균_영상간격점수', '평균 영상 좋아요 수 점수', '영상개수 점수', '성실도', '참여도', '인지도', '성장률',
#        '필터링전_총점', '필터링전_총_점수(확인용)', '점수 재조정_창수', '점수 재조정_다현', '필터링_취합', 'bool',
#        '최종_점수', '등급'],
#       dtype='object')

# %%
dates = ['22_08', '22_09', '22_10', '22_11', '22_12', '23_01', '23_02', '23_03', '23_04', '23_05', '23_06', '23_07', '23_08']

# %%
vars = ['구독자점수', '조회수점수', '충성도점수', '구독자 성장율점수', '감성점수점수', '평균_영상간격점수',
       '평균 영상 좋아요 수 점수', '영상개수 점수', '등급' ]

# %%
cols = []
for date in dates:
    for var in vars:
        cols.append(date + '_' + var)
cols
# Out:
# ['22_08_구독자점수',
#  '22_08_조회수점수',
#  '22_08_충성도점수',
#  '22_08_구독자 성장율점수',
#  '22_08_감성점수점수',
#  '22_08_평균_영상간격점수',
#  '22_08_평균 영상 좋아요 수 점수',
#  '22_08_영상개수 점수',
#  '22_08_등급',
#  '22_09_구독자점수',
#  '22_09_조회수점수',
#  '22_09_충성도점수',
#  '22_09_구독자 성장율점수',
#  '22_09_감성점수점수',
#  '22_09_평균_영상간격점수',
#  '22_09_평균 영상 좋아요 수 점수',
#  '22_09_영상개수 점수',
#  '22_09_등급',
#  '22_10_구독자점수',
#  '22_10_조회수점수',
#  '22_10_충성도점수',
#  '22_10_구독자 성장율점수',
#  '22_10_감성점수점수',
#  '22_10_평균_영상간격점수',
#  '22_10_평균 영상 좋아요 수 점수',
#  '22_10_영상개수 점수',
#  '22_10_등급',
#  '22_11_구독자점수',
#  '22_11_조회수점수',
#  '22_11_충성도점수',
#  '22_11_구독자 성장율점수',
#  '22_11_감성점수점수',
#  '22_11_평균_영상간격점수',
#  '22_11_평균 영상 좋아요 수 점수',
#  '22_11_영상개수 점수',
#  '22_11_등급',
#  '22_12_구독자점수',
#  '22_12_조회수점수',
#  '22_12_충성도점수',
#  '22_12_구독자 성장율점수',
#  '22_12_감성점수점수',
#  '22_12_평균_영상간격점수',
#  '22_12_평균 영상 좋아요 수 점수',
#  '22_12_영상개수 점수',
#  '22_12_등급',
#  '23_01_구독자점수',
#  '23_01_조회수점수',
#  '23_01_충성도점수',
#  '23_01_구독자 성장율점수',
#  '23_01_감성점수점수',
#  '23_01_평균_영상간격점수',
#  '23_01_평균 영상 좋아요 수 점수',
#  '23_01_영상개수 점수',
#  '23_01_등급',
#  '23_02_구독자점수',
#  '23_02_조회수점수',
#  '23_02_충성도점수',
#  '23_02_구독자 성장율점수',
#  '23_02_감성점수점수',
#  '23_02_평균_영상간격점수',
#  '23_02_평균 영상 좋아요 수 점수',
#  '23_02_영상개수 점수',
#  '23_02_등급',
#  '23_03_구독자점수',
#  '23_03_조회수점수',
#  '23_03_충성도점수',
#  '23_03_구독자 성장율점수',
#  '23_03_감성점수점수',
#  '23_03_평균_영상간격점수',
#  '23_03_평균 영상 좋아요 수 점수',
#  '23_03_영상개수 점수',
#  '23_03_등급',
#  '23_04_구독자점수',
#  '23_04_조회수점수',
#  '23_04_충성도점수',
#  '23_04_구독자 성장율점수',
#  '23_04_감성점수점수',
#  '23_04_평균_영상간격점수',
#  '23_04_평균 영상 좋아요 수 점수',
#  '23_04_영상개수 점수',
#  '23_04_등급',
#  '23_05_구독자점수',
#  '23_05_조회수점수',
#  '23_05_충성도점수',
#  '23_05_구독자 성장율점수',
#  '23_05_감성점수점수',
#  '23_05_평균_영상간격점수',
#  '23_05_평균 영상 좋아요 수 점수',
#  '23_05_영상개수 점수',
#  '23_05_등급',
#  '23_06_구독자점수',
#  '23_06_조회수점수',
#  '23_06_충성도점수',
#  '23_06_구독자 성장율점수',
#  '23_06_감성점수점수',
#  '23_06_평균_영상간격점수',
#  '23_06_평균 영상 좋아요 수 점수',
#  '23_06_영상개수 점수',
#  '23_06_등급',
#  '23_07_구독자점수',
#  '23_07_조회수점수',
#  '23_07_충성도점수',
#  '23_07_구독자 성장율점수',
#  '23_07_감성점수점수',
#  '23_07_평균_영상간격점수',
#  '23_07_평균 영상 좋아요 수 점수',
#  '23_07_영상개수 점수',
#  '23_07_등급',
#  '23_08_구독자점수',
#  '23_08_조회수점수',
#  '23_08_충성도점수',
#  '23_08_구독자 성장율점수',
#  '23_08_감성점수점수',
#  '23_08_평균_영상간격점수',
#  '23_08_평균 영상 좋아요 수 점수',
#  '23_08_영상개수 점수',
#  '23_08_등급']

# %% [markdown]
# # 데이터프레임 형태 변환

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', '유투버', '월', '연도',
#        '평균 조회수', '평균 영상 좋아요 수', '영상개수', '구독자', '구독자 성장율', '감성점수', '평균_영상간격',
#        'null_지속', '충성시청자_비율', '구독자점수', '조회수점수', '충성도점수', '구독자 성장율점수', '감성점수점수',
#        '평균_영상간격점수', '평균 영상 좋아요 수 점수', '영상개수 점수', '성실도', '참여도', '인지도', '성장률',
#        '필터링전_총점', '필터링전_총_점수(확인용)', '점수 재조정_창수', '점수 재조정_다현', '필터링_취합', 'bool',
#        '최종_점수', '등급'],
#       dtype='object')

# %%
list(df.columns).index('구독자점수')
# Out:
# 15

# %%
df_new = pd.DataFrame(columns=['유투버'] + cols)
for name_idx, name in enumerate(df['유투버'].unique()):
    df_new.loc[name_idx, '유투버'] = name
    for i, date in enumerate(dates):
        start_name = df_new.columns[i*9+1]
        end_name = df_new.columns[(i+1)*9]
        df_new.loc[name_idx, start_name:end_name] = df[df['유투버'] == name].iloc[i, [15, 16, 17, 18, 19, 20, 21, 22, -1]].values

# %%
df_new
# Out:
#                   유투버 22_08_구독자점수 22_08_조회수점수 22_08_충성도점수 22_08_구독자 성장율점수  \
# 0           @Mingokim         0.0           0           0             7.5
# 1         @yekooooong        3.75           6           8             7.5
# 2      benny8282_nail         7.5           3           2             7.5
# 3             bird 정은        3.75           0           0             7.5
# 4          Coco Riley        15.0           0           0             0.0
# ..                ...         ...         ...         ...             ...
# 242              회사원A        15.0          15           4             5.0
# 243               효진조        15.0          15           4             5.0
# 244  후니세탁소HUNILAUNDRY         0.0          15           2             0.0
# 245   후메이크업whozmakeup         7.5           3           2             0.0
# 246                희주        15.0          15           2             7.5
#
#     22_08_감성점수점수 22_08_평균_영상간격점수 22_08_평균 영상 좋아요 수 점수 22_08_영상개수 점수 22_08_등급  \
# 0              0               0                    0             0        E
# 1              2               6                    4             6       C+
# 2              4               3                    4             3       C0
# 3              0               0                    0             0       D+
# 4              0               0                    0             0       C0
# ..           ...             ...                  ...           ...      ...
# 242            8              12                   10             9       A0
# 243            6              15                   10            12       A+
# 244            2               0                    4             3       D+
# 245            8               3                    2             3       D+
# 246            6               6                   10             3       B+
#
#      ... 23_07_등급 23_08_구독자점수 23_08_조회수점수 23_08_충성도점수 23_08_구독자 성장율점수  \
# 0    ...       D0         0.0           0           0             7.5
# 1    ...       C+         7.5           6           6             7.5
# 2    ...       D+         7.5           3           2             7.5
# 3    ...       C0        3.75           9           2             7.5
# 4    ...       B0        15.0           6           8             0.0
# ..   ...      ...         ...         ...         ...             ...
# 242  ...       A0        15.0          15           4             5.0
# 243  ...       A0        15.0          15           4             0.0
# 244  ...       D+         0.0           6           2             7.5
# 245  ...       C+         7.5           6           8             5.0
# 246  ...       A0        15.0          15           6             0.0
#
#     23_08_감성점수점수 23_08_평균_영상간격점수 23_08_평균 영상 좋아요 수 점수 23_08_영상개수 점수 23_08_등급
# 0              0               0                    0             0        E
# 1              8              12                    4             9       B+
# 2              2               0                    2             3       D+
# 3              4               0                    6             3       C0
# 4              8               9                    4             9       B0
# ..           ...             ...                  ...           ...      ...
# 242            4              12                   10             9       A0
# 243            6              15                   10            12       A0
# 244            4              12                    2             3       C0
# 245            8              12                    2             9       B0
# 246            4               3                    8             3       B0
#
# [247 rows x 118 columns]

# %%
df_new.columns
# Out:
# Index(['유투버', '22_08_구독자점수', '22_08_조회수점수', '22_08_충성도점수', '22_08_구독자 성장율점수',
#        '22_08_감성점수점수', '22_08_평균_영상간격점수', '22_08_평균 영상 좋아요 수 점수',
#        '22_08_영상개수 점수', '22_08_등급',
#        ...
#        '23_07_등급', '23_08_구독자점수', '23_08_조회수점수', '23_08_충성도점수',
#        '23_08_구독자 성장율점수', '23_08_감성점수점수', '23_08_평균_영상간격점수',
#        '23_08_평균 영상 좋아요 수 점수', '23_08_영상개수 점수', '23_08_등급'],
#       dtype='object', length=118)

# %%
df_new.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # 3개월 데이터만 사용

# %% [markdown]
# ## 등급 자체를 예측

# %%
y_test = df_new.iloc[:, [-1]]
y_test
# Out:
#     23_08_등급
# 0          E
# 1         B+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       C0
# 245       B0
# 246       B0
#
# [247 rows x 1 columns]

# %%
X_test = pd.concat(( df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19], df_new.iloc[:, -18:-10]), axis=1)
X_train = pd.concat(( df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19]), axis=1)

# %%
y_train = df_new.iloc[:, [-10]]
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_train)
scaled_features = pd.DataFrame(scaled_features, columns = X_train.columns)
# 데이터 변환

X_tr= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_train.columns[:8].str.replace('15년_', ''))
    for j in range(3):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_tr.append(temp_df.values)

X_tr= np.array(X_tr)
y_tr = np.array(y_train.values)
X_tr.shape, y_tr.shape
# Out:
# ((247, 3, 8), (247, 1))

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_test)
scaled_features = pd.DataFrame(scaled_features, columns = X_test.columns)
# 데이터 변환

X_te= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_test.columns[:8].str.replace('15년_', ''))
    for j in range(3):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_te.append(temp_df.values)

X_te= np.array(X_te)
y_te = np.array(y_test.values)
X_te.shape, y_te.shape
# Out:
# ((247, 3, 8), (247, 1))

# %%
def label_encode_dataframe(df, column_name):
    label_mapping = {
        'A+': 0, 'A0': 1, 'B+': 2, 'B0': 3,
        'C+': 4, 'C0': 5, 'D+': 6, 'D0': 7,
        'E': 8, 'F': 9
    }
    df[column_name] = df[column_name].map(label_mapping)
    return df

# %%
label_encode_dataframe(y_train, y_train.columns[0])
label_encode_dataframe(y_test, y_test.columns[0])
# Out:
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\1625537586.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\1625537586.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
#      23_08_등급
# 0           8
# 1           2
# 2           6
# 3           5
# 4           3
# ..        ...
# 242         1
# 243         1
# 244         5
# 245         3
# 246         3
#
# [247 rows x 1 columns]

# %%
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
X_tr.shape
# Out:
# (247, 3, 8)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# 시계열 데이터 생성 (예제 데이터)
# X: 시계열 특성 데이터, y: 다중 클래스 레이블
# 이 예제에서는 임의의 데이터를 생성합니다. 실제 데이터에 대한 적용을 위해 데이터를 준비해야 합니다.

X_tr = tf.convert_to_tensor(X_tr, dtype=tf.float32)
X_te = tf.convert_to_tensor(X_te, dtype=tf.float32)

# LSTM 모델 생성
model = Sequential()
# model.add(LSTM(units=128, input_shape=(3, 8), return_sequences=True))
model.add(LSTM(units=64,  input_shape=(3, 8)))
model.add(Dense(units=10, activation='softmax'))

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 저장 콜백 설정
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, save_weights_only=False, monitor='val_loss', mode='min', verbose=1)

# 모델 학습
history = model.fit(X_tr, y_train, epochs=100, batch_size=16, validation_data=(X_te, y_test), callbacks=[early_stopping, model_checkpoint])

# 모델 평가
loss, accuracy = model.evaluate(X_te, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 2.2512 - accuracy: 0.1903
# Epoch 1: val_loss improved from inf to 2.19367, saving model to best_model.h5
# 16/16 [==============================] - 3s 49ms/step - loss: 2.2512 - accuracy: 0.1903 - val_loss: 2.1937 - val_accuracy: 0.1822
# Epoch 2/100
# 15/16 [===========================>..] - ETA: 0s - loss: 2.1381 - accuracy: 0.1833
# Epoch 2: val_loss improved from 2.19367 to 2.09852, saving model to best_model.h5
# 16/16 [==============================] - 0s 13ms/step - loss: 2.1365 - accuracy: 0.1781 - val_loss: 2.0985 - val_accuracy: 0.1700
# Epoch 3/100
# 12/16 [=====================>........] - ETA: 0s - loss: 2.0438 - accuracy: 0.1719
# Epoch 3: val_loss improved from 2.09852 to 2.03634, saving model to best_model.h5
# 16/16 [==============================] - 0s 11ms/step - loss: 2.0384 - accuracy: 0.1700 - val_loss: 2.0363 - val_accuracy: 0.1741
# Epoch 4/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9792 - accuracy: 0.1958
# Epoch 4: val_loss improved from 2.03634 to 2.00169, saving model to best_model.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 1.9743 - accuracy: 0.1943 - val_loss: 2.0017 - val_accuracy: 0.1903
# Epoch 5/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9325 - accuracy: 0.2292
# Epoch 5: val_loss improved from 2.00169 to 1.97098, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 1.9322 - accuracy: 0.2308 - val_loss: 1.9710 - val_accuracy: 0.2186
# Epoch 6/100
#  1/16 [>.............................] - ETA: 0s - loss: 1.8548 - accuracy: 0.1875
# Epoch 6: val_loss improved from 1.97098 to 1.93026, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 1.8896 - accuracy: 0.2632 - val_loss: 1.9303 - val_accuracy: 0.2955
# Epoch 7/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.8518 - accuracy: 0.2667
# Epoch 7: val_loss improved from 1.93026 to 1.89012, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 1.8453 - accuracy: 0.2794 - val_loss: 1.8901 - val_accuracy: 0.2834
# Epoch 8/100
#  1/16 [>.............................] - ETA: 0s - loss: 1.7028 - accuracy: 0.3750
# Epoch 8: val_loss improved from 1.89012 to 1.84490, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 1.7926 - accuracy: 0.3077 - val_loss: 1.8449 - val_accuracy: 0.2713
# Epoch 9/100
#  1/16 [>.............................] - ETA: 0s - loss: 2.0615 - accuracy: 0.3125
# Epoch 9: val_loss improved from 1.84490 to 1.80096, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 1.7433 - accuracy: 0.3158 - val_loss: 1.8010 - val_accuracy: 0.2672
# Epoch 10/100
#  1/16 [>.............................] - ETA: 0s - loss: 1
100
# 14/16 [=========================>....] - ETA: 0s - loss: 1.3457 - accuracy: 0.4688
# Epoch 56: val_loss did not improve from 1.51420
# 16/16 [==============================] - 0s 9ms/step - loss: 1.3543 - accuracy: 0.4615 - val_loss: 1.5287 - val_accuracy: 0.4008
# Epoch 57/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.3681 - accuracy: 0.4583
# Epoch 57: val_loss did not improve from 1.51420
# 16/16 [==============================] - 0s 10ms/step - loss: 1.3459 - accuracy: 0.4818 - val_loss: 1.5207 - val_accuracy: 0.3968
# Epoch 58/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.3046 - accuracy: 0.5260
# Epoch 58: val_loss did not improve from 1.51420
# 16/16 [==============================] - 0s 8ms/step - loss: 1.3367 - accuracy: 0.4899 - val_loss: 1.5366 - val_accuracy: 0.4008
# Epoch 59/100
# 16/16 [==============================] - ETA: 0s - loss: 1.3347 - accuracy: 0.4737
# Epoch 59: val_loss did not improve from 1.51420
# 16/16 [==============================] - 0s 8ms/step - loss: 1.3347 - accuracy: 0.4737 - val_loss: 1.5252 - val_accuracy: 0.3806
# 8/8 [==============================] - 0s 3ms/step - loss: 1.5142 - accuracy: 0.4008
# Test Loss: 1.5142, Test Accuracy: 0.4008

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(X_te)


y_pred_classes = np.argmax(predictions, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# 정확도 계산
accuracy = accuracy_score(y_true_classes, y_pred_classes)

# 정밀도 계산
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')

# 재현율 계산
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')

# F1 스코어 계산
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.4008097165991903
# Precision: 0.3581828052056155
# Recall: 0.4008097165991903
# F1 score: 0.3767678048112224
# c:\anaconda3\envs\py_397\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## 간소화된 등급 예측

# %%
y_test = df_new.iloc[:, [-1]]
y_test
# Out:
#     23_08_등급
# 0          E
# 1         B+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       C0
# 245       B0
# 246       B0
#
# [247 rows x 1 columns]

# %%
X_test = pd.concat(( df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19], df_new.iloc[:, -18:-10]), axis=1)
X_train = pd.concat(( df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19]), axis=1)

# %%
y_train = df_new.iloc[:, [-10]]
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_train)
scaled_features = pd.DataFrame(scaled_features, columns = X_train.columns)
# 데이터 변환

X_tr= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_train.columns[:8].str.replace('15년_', ''))
    for j in range(3):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_tr.append(temp_df.values)

X_tr= np.array(X_tr)
y_tr = np.array(y_train.values)
X_tr.shape, y_tr.shape
# Out:
# ((247, 3, 8), (247, 1))

# %%
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_test)
scaled_features = pd.DataFrame(scaled_features, columns = X_test.columns)
# 데이터 변환

X_te= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_test.columns[:8].str.replace('15년_', ''))
    for j in range(3):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_te.append(temp_df.values)

X_te= np.array(X_te)
y_te = np.array(y_test.values)
X_te.shape, y_te.shape
# Out:
# ((247, 3, 8), (247, 1))

# %%
def label_encode_dataframe_2(df, column_name):
    label_mapping = {
        'A+': 0, 'A0': 0, 'B+': 1, 'B0': 1,
        'C+': 2, 'C0': 2, 'D+': 3, 'D0': 3,
        'E': 4, 'F': 4
    }
    df[column_name] = df[column_name].map(label_mapping)
    return df

# %%
label_encode_dataframe_2(y_train, y_train.columns[0])
label_encode_dataframe_2(y_test, y_test.columns[0])
# Out:
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\3906280974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\3906280974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
#      23_08_등급
# 0           4
# 1           1
# 2           3
# 3           2
# 4           1
# ..        ...
# 242         0
# 243         0
# 244         2
# 245         1
# 246         1
#
# [247 rows x 1 columns]

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# 시계열 데이터 생성 (예제 데이터)
# X: 시계열 특성 데이터, y: 다중 클래스 레이블
# 이 예제에서는 임의의 데이터를 생성합니다. 실제 데이터에 대한 적용을 위해 데이터를 준비해야 합니다.

X_tr = tf.convert_to_tensor(X_tr, dtype=tf.float32)
X_te = tf.convert_to_tensor(X_te, dtype=tf.float32)

# LSTM 모델 생성
model = Sequential()
# model.add(LSTM(units=128, input_shape=(3, 8), return_sequences=True))
model.add(LSTM(units=64,  input_shape=(3, 8)))
model.add(Dense(units=5, activation='softmax'))

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 저장 콜백 설정
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, save_weights_only=False, monitor='val_loss', mode='min', verbose=1)

# 모델 학습
history = model.fit(X_tr, y_train, epochs=100, batch_size=16, validation_data=(X_te, y_test), callbacks=[early_stopping, model_checkpoint])

# 모델 평가
loss, accuracy = model.evaluate(X_te, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100
#  1/16 [>.............................] - ETA: 38s - loss: 1.6335 - accuracy: 0.2500
# Epoch 1: val_loss improved from inf to 1.47647, saving model to best_model.h5
# 16/16 [==============================] - 4s 67ms/step - loss: 1.5612 - accuracy: 0.2348 - val_loss: 1.4765 - val_accuracy: 0.3279
# Epoch 2/100
# 13/16 [=======================>......] - ETA: 0s - loss: 1.4233 - accuracy: 0.3269
# Epoch 2: val_loss improved from 1.47647 to 1.39272, saving model to best_model.h5
# 16/16 [==============================] - 0s 13ms/step - loss: 1.4167 - accuracy: 0.3279 - val_loss: 1.3927 - val_accuracy: 0.3279
# Epoch 3/100
# 13/16 [=======================>......] - ETA: 0s - loss: 1.3642 - accuracy: 0.3269
# Epoch 3: val_loss improved from 1.39272 to 1.35059, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 1.3503 - accuracy: 0.3360 - val_loss: 1.3506 - val_accuracy: 0.3725
# Epoch 4/100
# 10/16 [=================>............] - ETA: 0s - loss: 1.3509 - accuracy: 0.3812
# Epoch 4: val_loss improved from 1.35059 to 1.30987, saving model to best_model.h5
# 16/16 [==============================] - 0s 13ms/step - loss: 1.3046 - accuracy: 0.4089 - val_loss: 1.3099 - val_accuracy: 0.3887
# Epoch 5/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.2650 - accuracy: 0.4375
# Epoch 5: val_loss improved from 1.30987 to 1.27046, saving model to best_model.h5
# 16/16 [==============================] - 0s 13ms/step - loss: 1.2554 - accuracy: 0.4372 - val_loss: 1.2705 - val_accuracy: 0.4291
# Epoch 6/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.1853 - accuracy: 0.4792
# Epoch 6: val_loss improved from 1.27046 to 1.21586, saving model to best_model.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 1.2076 - accuracy: 0.4615 - val_loss: 1.2159 - val_accuracy: 0.4534
# Epoch 7/100
# 10/16 [=================>............] - ETA: 0s - loss: 1.1461 - accuracy: 0.5063
# Epoch 7: val_loss improved from 1.21586 to 1.16888, saving model to best_model.h5
# 16/16 [==============================] - 0s 11ms/step - loss: 1.1549 - accuracy: 0.5101 - val_loss: 1.1689 - val_accuracy: 0.4777
# Epoch 8/100
# 14/16 [=========================>....] - ETA: 0s - loss: 1.0931 - accuracy: 0.5268
# Epoch 8: val_loss improved from 1.16888 to 1.12851, saving model to best_model.h5
# 16/16 [==============================] - 0s 10ms/step - loss: 1.1005 - accuracy: 0.5101 - val_loss: 1.1285 - val_accuracy: 0.4615
# Epoch 9/100
# 11/16 [===================>..........] - ETA: 0s - loss: 1.0715 - accuracy: 0.5227
# Epoch 9: val_loss improved from 1.12851 to 1.09481, saving model to best_model.h5
# 16/16 [==============================] - 0s 14ms/step - loss: 1.0684 - accuracy: 0.5101 - val_loss: 1.0948 - val_accuracy: 0.4656
# Epoch 10/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.0467 - accuracy: 0.4948
# Epoch 10: val_loss improved from 1.09481 to 1.08499, saving model to best_model.h5
# 16/16 [==============================] - 0s 13ms/step - loss: 1.0276 - accuracy: 0.5182 - val_loss: 1.0850 - val_accuracy: 0.4534
# Epoch 11/100
#  8/16 [==============>...............] - ETA: 0s - loss: 0.9586 - accuracy: 0.5547
# Epoch 11: val_loss improved from 1.08499 to 1.08167, saving model to best_model.h5
# 16/16 [==============================] - 0s 16ms/step - loss:
100
# 10/16 [=================>............] - ETA: 0s - loss: 0.7894 - accuracy: 0.6562
# Epoch 59: val_loss did not improve from 0.90296
# 16/16 [==============================] - 0s 13ms/step - loss: 0.8393 - accuracy: 0.6518 - val_loss: 0.9133 - val_accuracy: 0.5587
# Epoch 60/100
#  9/16 [===============>..............] - ETA: 0s - loss: 0.8041 - accuracy: 0.6736
# Epoch 60: val_loss improved from 0.90296 to 0.89768, saving model to best_model.h5
# 16/16 [==============================] - 0s 16ms/step - loss: 0.8392 - accuracy: 0.6518 - val_loss: 0.8977 - val_accuracy: 0.5668
# Epoch 61/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.8069 - accuracy: 0.6705
# Epoch 61: val_loss did not improve from 0.89768
# 16/16 [==============================] - 0s 13ms/step - loss: 0.8428 - accuracy: 0.6356 - val_loss: 0.9205 - val_accuracy: 0.5587
# Epoch 62/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.8586 - accuracy: 0.6417
# Epoch 62: val_loss did not improve from 0.89768
# 16/16 [==============================] - 0s 21ms/step - loss: 0.8511 - accuracy: 0.6437 - val_loss: 0.9104 - val_accuracy: 0.5668
# Epoch 63/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.8474 - accuracy: 0.6071
# Epoch 63: val_loss did not improve from 0.89768
# 16/16 [==============================] - 0s 9ms/step - loss: 0.8528 - accuracy: 0.6194 - val_loss: 0.9185 - val_accuracy: 0.5547
# Epoch 64/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.8197 - accuracy: 0.6518
# Epoch 64: val_loss did not improve from 0.89768
# 16/16 [==============================] - 0s 8ms/step - loss: 0.8374 - accuracy: 0.6437 - val_loss: 0.9113 - val_accuracy: 0.5668
# Epoch 65/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.8471 - accuracy: 0.6250
# Epoch 65: val_loss did not improve from 0.89768
# 16/16 [==============================] - 0s 9ms/step - loss: 0.8331 - accuracy: 0.6275 - val_loss: 0.9069 - val_accuracy: 0.5587
# 8/8 [==============================] - 0s 3ms/step - loss: 0.8977 - accuracy: 0.5668
# Test Loss: 0.8977, Test Accuracy: 0.5668

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(X_te)


y_pred_classes = np.argmax(predictions, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# 정확도 계산
accuracy = accuracy_score(y_true_classes, y_pred_classes)

# 정밀도 계산
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')

# 재현율 계산
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')

# F1 스코어 계산
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.5668016194331984
# Precision: 0.5637676499745466
# Recall: 0.5668016194331984
# F1 score: 0.5640672645481518

# %% [markdown]
# ## 인기, 비인기 예측

# %%
y_test = df_new.iloc[:, [-1]]
y_test
# Out:
#     23_08_등급
# 0          E
# 1         B+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       C0
# 245       B0
# 246       B0
#
# [247 rows x 1 columns]

# %%
X_test = pd.concat(( df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19], df_new.iloc[:, -18:-10]), axis=1)
X_train = pd.concat(( df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19]), axis=1)

# %%
y_train = df_new.iloc[:, [-10]]
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_train)
scaled_features = pd.DataFrame(scaled_features, columns = X_train.columns)
# 데이터 변환

X_tr= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_train.columns[:8].str.replace('15년_', ''))
    for j in range(3):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_tr.append(temp_df.values)

X_tr= np.array(X_tr)
y_tr = np.array(y_train.values)
X_tr.shape, y_tr.shape
# Out:
# ((247, 3, 8), (247, 1))

# %%
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_test)
scaled_features = pd.DataFrame(scaled_features, columns = X_test.columns)
# 데이터 변환

X_te= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_test.columns[:8].str.replace('15년_', ''))
    for j in range(3):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_te.append(temp_df.values)

X_te= np.array(X_te)
y_te = np.array(y_test.values)
X_te.shape, y_te.shape
# Out:
# ((247, 3, 8), (247, 1))

# %%
def label_encode_dataframe_3(df, column_name):
    label_mapping = {
        'A+': 0, 'A0': 0, 'B+': 0, 'B0': 0,
        'C+': 1, 'C0': 1, 'D+': 1, 'D0': 1,
        'E': 1, 'F': 1
    }
    df[column_name] = df[column_name].map(label_mapping)
    return df

# %%
label_encode_dataframe_3(y_train, y_train.columns[0])
label_encode_dataframe_3(y_test, y_test.columns[0])
# Out:
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\2928109579.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\2928109579.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
#      23_08_등급
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# ..        ...
# 242         0
# 243         0
# 244         1
# 245         0
# 246         0
#
# [247 rows x 1 columns]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# 시계열 데이터 생성 (예제 데이터)
# X: 시계열 특성 데이터, y: 다중 클래스 레이블
# 이 예제에서는 임의의 데이터를 생성합니다. 실제 데이터에 대한 적용을 위해 데이터를 준비해야 합니다.

X_tr = tf.convert_to_tensor(X_tr, dtype=tf.float32)
X_te = tf.convert_to_tensor(X_te, dtype=tf.float32)

# LSTM 모델 생성
model = Sequential()
# model.add(LSTM(units=128, input_shape=(3, 8), return_sequences=True))
model.add(LSTM(units=64,  input_shape=(3, 8)))
model.add(Dense(units=1, activation='sigmoid'))

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 저장 콜백 설정
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, save_weights_only=False, monitor='val_loss', mode='min', verbose=1)

# 모델 학습
history = model.fit(X_tr, y_train, epochs=100, batch_size=16, validation_data=(X_te, y_test), callbacks=[early_stopping, model_checkpoint])

# 모델 평가
loss, accuracy = model.evaluate(X_te, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100
# 12/16 [=====================>........] - ETA: 0s - loss: 0.6719 - accuracy: 0.5573
# Epoch 1: val_loss improved from inf to 0.63503, saving model to best_model.h5
# 16/16 [==============================] - 5s 73ms/step - loss: 0.6673 - accuracy: 0.5466 - val_loss: 0.6350 - val_accuracy: 0.5911
# Epoch 2/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.6202 - accuracy: 0.6429
# Epoch 2: val_loss improved from 0.63503 to 0.59487, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6167 - accuracy: 0.6518 - val_loss: 0.5949 - val_accuracy: 0.7004
# Epoch 3/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.5730 - accuracy: 0.7500
# Epoch 3: val_loss improved from 0.59487 to 0.54402, saving model to best_model.h5
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5703 - accuracy: 0.7530 - val_loss: 0.5440 - val_accuracy: 0.7733
# Epoch 4/100
# 13/16 [=======================>......] - ETA: 0s - loss: 0.5220 - accuracy: 0.7981
# Epoch 4: val_loss improved from 0.54402 to 0.48576, saving model to best_model.h5
# 16/16 [==============================] - 0s 11ms/step - loss: 0.5128 - accuracy: 0.8057 - val_loss: 0.4858 - val_accuracy: 0.8178
# Epoch 5/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.4480 - accuracy: 0.8259
# Epoch 5: val_loss improved from 0.48576 to 0.43722, saving model to best_model.h5
# 16/16 [==============================] - 0s 10ms/step - loss: 0.4483 - accuracy: 0.8300 - val_loss: 0.4372 - val_accuracy: 0.8300
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.8502
# Epoch 6: val_loss improved from 0.43722 to 0.41583, saving model to best_model.h5
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3989 - accuracy: 0.8502 - val_loss: 0.4158 - val_accuracy: 0.8340
# Epoch 7/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.3579 - accuracy: 0.8807
# Epoch 7: val_loss improved from 0.41583 to 0.41301, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3742 - accuracy: 0.8543 - val_loss: 0.4130 - val_accuracy: 0.8219
# Epoch 8/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3584 - accuracy: 0.8583
# Epoch 8: val_loss improved from 0.41301 to 0.40657, saving model to best_model.h5
# 16/16 [==============================] - 0s 9ms/step - loss: 0.3620 - accuracy: 0.8583 - val_loss: 0.4066 - val_accuracy: 0.8178
# Epoch 9/100
#  1/16 [>.............................] - ETA: 0s - loss: 0.1903 - accuracy: 0.9375
# Epoch 9: val_loss improved from 0.40657 to 0.40459, saving model to best_model.h5
# 16/16 [==============================] - 0s 8ms/step - loss: 0.3573 - accuracy: 0.8583 - val_loss: 0.4046 - val_accuracy: 0.8138
# Epoch 10/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3634 - accuracy: 0.8625
# Epoch 10: val_loss improved from 0.40459 to 0.39362, saving model to best_model.h5
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3556 - accuracy: 0.8664 - val_loss: 0.3936 - val_accuracy: 0.8300
# Epoch 11/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3563 - accuracy: 0.8500
# Epoch 11: val_loss did not improve from 0.39362
# 16/16 [==============================] - 0s 14ms/step - loss: 0.3525 - accuracy: 0.8502 - val_loss: 0.3947 - val_accuracy: 0.8178
# Epoch 12/100
# 13/16 [=======================>......] - ETA: 0s - loss: 0.
100
# 10/16 [=================>............] - ETA: 0s - loss: 0.3319 - accuracy: 0.8687
# Epoch 45: val_loss did not improve from 0.33140
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3037 - accuracy: 0.8785 - val_loss: 0.3317 - val_accuracy: 0.8381
# Epoch 46/100
# 13/16 [=======================>......] - ETA: 0s - loss: 0.3139 - accuracy: 0.8894
# Epoch 46: val_loss improved from 0.33140 to 0.33112, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.3011 - accuracy: 0.8907 - val_loss: 0.3311 - val_accuracy: 0.8381
# Epoch 47/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.2713 - accuracy: 0.9034
# Epoch 47: val_loss did not improve from 0.33112
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3037 - accuracy: 0.8826 - val_loss: 0.3319 - val_accuracy: 0.8381
# Epoch 48/100
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2899 - accuracy: 0.8906
# Epoch 48: val_loss did not improve from 0.33112
# 16/16 [==============================] - 0s 10ms/step - loss: 0.3011 - accuracy: 0.8866 - val_loss: 0.3317 - val_accuracy: 0.8421
# Epoch 49/100
#  8/16 [==============>...............] - ETA: 0s - loss: 0.2892 - accuracy: 0.8906
# Epoch 49: val_loss did not improve from 0.33112
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3083 - accuracy: 0.8664 - val_loss: 0.3347 - val_accuracy: 0.8462
# Epoch 50/100
# 12/16 [=====================>........] - ETA: 0s - loss: 0.2774 - accuracy: 0.8854
# Epoch 50: val_loss improved from 0.33112 to 0.33052, saving model to best_model.h5
# 16/16 [==============================] - 0s 13ms/step - loss: 0.3002 - accuracy: 0.8826 - val_loss: 0.3305 - val_accuracy: 0.8462
# Epoch 51/100
#  8/16 [==============>...............] - ETA: 0s - loss: 0.3020 - accuracy: 0.8828
# Epoch 51: val_loss improved from 0.33052 to 0.33032, saving model to best_model.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 0.3023 - accuracy: 0.8947 - val_loss: 0.3303 - val_accuracy: 0.8421
# Epoch 52/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.2898 - accuracy: 0.8864
# Epoch 52: val_loss did not improve from 0.33032
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3051 - accuracy: 0.8826 - val_loss: 0.3326 - val_accuracy: 0.8462
# Epoch 53/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.3081 - accuracy: 0.8875
# Epoch 53: val_loss improved from 0.33032 to 0.32835, saving model to best_model.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2984 - accuracy: 0.8907 - val_loss: 0.3284 - val_accuracy: 0.8421
# Epoch 54/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.8947
# Epoch 54: val_loss did not improve from 0.32835
# 16/16 [==============================] - 0s 16ms/step - loss: 0.3014 - accuracy: 0.8947 - val_loss: 0.3301 - val_accuracy: 0.8381
# Epoch 55/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.3272 - accuracy: 0.8636
# Epoch 55: val_loss did not improve from 0.32835
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2999 - accuracy: 0.8826 - val_loss: 0.3293 - val_accuracy: 0.8421
# Epoch 56/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.3012 - accuracy: 0.8807
# Epoch 56: val_loss did not improve from 0.32835
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2945 - accuracy: 0.8826 - val_loss: 0.3316 - val_accuracy: 0.8462
# Epoch 57/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.2600 - accuracy: 0.9000
# Epoch 57: val_loss did not improve from 0.32835
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2978 - accuracy: 0.8866 - val_loss: 0.3364 - val_accuracy: 0.8421
# Epoch 58/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.2662 - accuracy: 0.9148
# Epoch 58: val_loss did not improve from 0.32835
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2952 - accuracy: 0.8988 - val_loss: 0.3308 - val_accuracy: 0.8381
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3284 - accuracy: 0.8421
# Test Loss: 0.3284, Test Accuracy: 0.8421

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(X_te)


y_pred = np.round(predictions)

# 정확도 계산
accuracy = accuracy_score(y_test, y_pred)

# 정밀도 계산
precision = precision_score(y_test, y_pred)

# 재현율 계산
recall = recall_score(y_test, y_pred)

# F1 스코어 계산
f1 = f1_score(y_test, y_pred)

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.8421052631578947
# Precision: 0.849624060150376
# Recall: 0.8560606060606061
# F1 score: 0.8528301886792453

# %% [markdown]
# # 데이터 전부 사용

# %% [markdown]
# ## 등급 자체를 예측

# %%
y_test = df_new.iloc[:, [-1]]
y_test
# Out:
#     23_08_등급
# 0          E
# 1         B+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       C0
# 245       B0
# 246       B0
#
# [247 rows x 1 columns]

# %%
X_test = pd.concat((df_new.iloc[:, -108:-100], df_new.iloc[:, -99:-91], df_new.iloc[:, -90:-82], df_new.iloc[:, -81:-73], df_new.iloc[:, -72:-64], df_new.iloc[:, -63:-55], df_new.iloc[:, -54:-46], df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19], df_new.iloc[:, -18:-10]), axis=1)
X_test
# Out:
#     22_09_구독자점수 22_09_조회수점수 22_09_충성도점수 22_09_구독자 성장율점수 22_09_감성점수점수  \
# 0           0.0           0           0             5.0            0
# 1          3.75           9           2             7.5            6
# 2           7.5           3           6             7.5            2
# 3          3.75           6           8             7.5            8
# 4          15.0           0           0             5.0            0
# ..          ...         ...         ...             ...          ...
# 242        15.0          15           4             5.0            6
# 243        15.0          15           4             5.0            6
# 244         0.0           0           0             5.0            0
# 245         7.5           6           8             0.0            6
# 246        15.0          15           6             7.5            4
#
#     22_09_평균_영상간격점수 22_09_평균 영상 좋아요 수 점수 22_09_영상개수 점수 22_10_구독자점수  \
# 0                 0                    0             0         0.0
# 1                 0                    4             3        3.75
# 2                 6                    4             6         7.5
# 3                12                    4             9        3.75
# 4                 0                    0             0        15.0
# ..              ...                  ...           ...         ...
# 242              15                   10             9        15.0
# 243              12                   10             9        15.0
# 244               0                    0             0         0.0
# 245              15                    2             9         7.5
# 246               6                   10             6        15.0
#
#     22_10_조회수점수  ... 23_06_평균 영상 좋아요 수 점수 23_06_영상개수 점수 23_07_구독자점수  \
# 0             0  ...                    0             0         0.0
# 1             0  ...                    6             9         7.5
# 2             3  ...                    2             3         7.5
# 3             9  ...                    0             0        3.75
# 4             9  ...                    4             9        15.0
# ..          ...  ...                  ...           ...         ...
# 242          15  ...                   10             9        15.0
# 243          15  ...                   10             9        15.0
# 244           9  ...                    2             3         0.0
# 245           3  ...                    2             6         7.5
# 246          15  ...                   10             9        15.0
#
#     23_07_조회수점수 23_07_충성도점수 23_07_구독자 성장율점수 23_07_감성점수점수 23_07_평균_영상간격점수  \
# 0             0           0             5.0            0               0
# 1             6           6             7.5            2               6
# 2             3           2             7.5            2               0
# 3             9           2             7.5            2               0
# 4             9           8             0.0            4               9
# ..          ...         ...             ...          ...             ...
# 242          15           4             5.0            4              12
# 243          15           6             7.5            8               6
# 244          12           2             7.5            2               0
# 245           3           8             5.0            8               6
# 246          15           6             7.5            6               9
#
#     23_07_평균 영상 좋아요 수 점수 23_07_영상개수 점수
# 0                      0             0
# 1                      4             3
# 2                      4             3
# 3                      6             3
# 4                      4             9
# ..                   ...           ...
# 242                   10             9
# 243                   10             9
# 244                    2             3
# 245                    2             6
# 246                   10             9
#
# [247 rows x 88 columns]

# %%
y_train = df_new.iloc[:, [-10]]
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
X_train = pd.concat((df_new.iloc[:, -117:-109], df_new.iloc[:, -108:-100], df_new.iloc[:, -99:-91], df_new.iloc[:, -90:-82], df_new.iloc[:, -81:-73], df_new.iloc[:, -72:-64], df_new.iloc[:, -63:-55], df_new.iloc[:, -54:-46], df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19]), axis=1)
X_train
# Out:
#     22_08_구독자점수 22_08_조회수점수 22_08_충성도점수 22_08_구독자 성장율점수 22_08_감성점수점수  \
# 0           0.0           0           0             7.5            0
# 1          3.75           6           8             7.5            2
# 2           7.5           3           2             7.5            4
# 3          3.75           0           0             7.5            0
# 4          15.0           0           0             0.0            0
# ..          ...         ...         ...             ...          ...
# 242        15.0          15           4             5.0            8
# 243        15.0          15           4             5.0            6
# 244         0.0          15           2             0.0            2
# 245         7.5           3           2             0.0            8
# 246        15.0          15           2             7.5            6
#
#     22_08_평균_영상간격점수 22_08_평균 영상 좋아요 수 점수 22_08_영상개수 점수 22_09_구독자점수  \
# 0                 0                    0             0         0.0
# 1                 6                    4             6        3.75
# 2                 3                    4             3         7.5
# 3                 0                    0             0        3.75
# 4                 0                    0             0        15.0
# ..              ...                  ...           ...         ...
# 242              12                   10             9        15.0
# 243              15                   10            12        15.0
# 244               0                    4             3         0.0
# 245               3                    2             3         7.5
# 246               6                   10             3        15.0
#
#     22_09_조회수점수  ... 23_05_평균 영상 좋아요 수 점수 23_05_영상개수 점수 23_06_구독자점수  \
# 0             0  ...                    2             3         0.0
# 1             9  ...                    6             3        3.75
# 2             3  ...                    4             6         7.5
# 3             6  ...                    4             6        3.75
# 4             0  ...                    4             9        15.0
# ..          ...  ...                  ...           ...         ...
# 242          15  ...                   10             9        15.0
# 243          15  ...                   10             9        15.0
# 244           0  ...                    0             0         0.0
# 245           6  ...                    2             9         7.5
# 246          15  ...                   10             6        15.0
#
#     23_06_조회수점수 23_06_충성도점수 23_06_구독자 성장율점수 23_06_감성점수점수 23_06_평균_영상간격점수  \
# 0             0           0             0.0            0               0
# 1            12           6             7.5            2               6
# 2             3           2             7.5           10               0
# 3             0           0             7.5            0               0
# 4             6           8             5.0            6               9
# ..          ...         ...             ...          ...             ...
# 242          15           4             5.0            6              15
# 243          15           6             7.5            6              12
# 244           3           2             0.0            2               0
# 245           3           6             5.0            6               3
# 246          15           8             7.5            4               9
#
#     23_06_평균 영상 좋아요 수 점수 23_06_영상개수 점수
# 0                      0             0
# 1                      6             9
# 2                      2             3
# 3                      0             0
# 4                      4             9
# ..                   ...           ...
# 242                   10             9
# 243                   10             9
# 244                    2             3
# 245                    2             6
# 246                   10             9
#
# [247 rows x 88 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_train)
scaled_features = pd.DataFrame(scaled_features, columns = X_train.columns)
# 데이터 변환

X_tr= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_train.columns[:8].str.replace('15년_', ''))
    for j in range(11):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_tr.append(temp_df.values)

X_tr= np.array(X_tr)
y_tr = np.array(y_train.values)
X_tr.shape, y_tr.shape
# Out:
# ((247, 11, 8), (247, 1))

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_test)
scaled_features = pd.DataFrame(scaled_features, columns = X_test.columns)
# 데이터 변환

X_te= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_test.columns[:8].str.replace('15년_', ''))
    for j in range(11):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_te.append(temp_df.values)

X_te= np.array(X_te)
y_te = np.array(y_test.values)
X_te.shape, y_te.shape
# Out:
# ((247, 11, 8), (247, 1))

# %%
def label_encode_dataframe(df, column_name):
    label_mapping = {
        'A+': 0, 'A0': 1, 'B+': 2, 'B0': 3,
        'C+': 4, 'C0': 5, 'D+': 6, 'D0': 7,
        'E': 8, 'F': 9
    }
    df[column_name] = df[column_name].map(label_mapping)
    return df

# %%
label_encode_dataframe(y_train, y_train.columns[0])
label_encode_dataframe(y_test, y_test.columns[0])
# Out:
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\1625537586.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\1625537586.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
#      23_08_등급
# 0           8
# 1           2
# 2           6
# 3           5
# 4           3
# ..        ...
# 242         1
# 243         1
# 244         5
# 245         3
# 246         3
#
# [247 rows x 1 columns]

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# 시계열 데이터 생성 (예제 데이터)
# X: 시계열 특성 데이터, y: 다중 클래스 레이블
# 이 예제에서는 임의의 데이터를 생성합니다. 실제 데이터에 대한 적용을 위해 데이터를 준비해야 합니다.

X_tr = tf.convert_to_tensor(X_tr, dtype=tf.float32)
X_te = tf.convert_to_tensor(X_te, dtype=tf.float32)

# LSTM 모델 생성
model = Sequential()
# model.add(LSTM(units=128, input_shape=(11, 8), return_sequences=True))
model.add(LSTM(units=64,  input_shape=(11, 8)))
model.add(Dense(units=10, activation='softmax'))

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 저장 콜백 설정
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, save_weights_only=False, monitor='val_loss', mode='min', verbose=1)

# 모델 학습
history = model.fit(X_tr, y_train, epochs=100, batch_size=16, validation_data=(X_te, y_test), callbacks=[early_stopping, model_checkpoint])

# 모델 평가
loss, accuracy = model.evaluate(X_te, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100
# 11/16 [===================>..........] - ETA: 0s - loss: 2.2204 - accuracy: 0.1364
# Epoch 1: val_loss improved from inf to 2.08863, saving model to best_model.h5
# 16/16 [==============================] - 4s 73ms/step - loss: 2.1790 - accuracy: 0.1619 - val_loss: 2.0886 - val_accuracy: 0.1903
# Epoch 2/100
# 12/16 [=====================>........] - ETA: 0s - loss: 2.0201 - accuracy: 0.1927
# Epoch 2: val_loss improved from 2.08863 to 2.01209, saving model to best_model.h5
# 16/16 [==============================] - 0s 21ms/step - loss: 2.0133 - accuracy: 0.1862 - val_loss: 2.0121 - val_accuracy: 0.1822
# Epoch 3/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.9267 - accuracy: 0.2125
# Epoch 3: val_loss improved from 2.01209 to 1.93593, saving model to best_model.h5
# 16/16 [==============================] - 0s 22ms/step - loss: 1.9344 - accuracy: 0.2065 - val_loss: 1.9359 - val_accuracy: 0.2510
# Epoch 4/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.8520 - accuracy: 0.2604
# Epoch 4: val_loss improved from 1.93593 to 1.83059, saving model to best_model.h5
# 16/16 [==============================] - 0s 19ms/step - loss: 1.8388 - accuracy: 0.2591 - val_loss: 1.8306 - val_accuracy: 0.2955
# Epoch 5/100
# 11/16 [===================>..........] - ETA: 0s - loss: 1.6990 - accuracy: 0.3466
# Epoch 5: val_loss improved from 1.83059 to 1.74268, saving model to best_model.h5
# 16/16 [==============================] - 0s 22ms/step - loss: 1.7079 - accuracy: 0.3239 - val_loss: 1.7427 - val_accuracy: 0.3117
# Epoch 6/100
# 14/16 [=========================>....] - ETA: 0s - loss: 1.6587 - accuracy: 0.3259
# Epoch 6: val_loss improved from 1.74268 to 1.71770, saving model to best_model.h5
# 16/16 [==============================] - 0s 24ms/step - loss: 1.6562 - accuracy: 0.3198 - val_loss: 1.7177 - val_accuracy: 0.3198
# Epoch 7/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1
100
# 13/16 [=======================>......] - ETA: 0s - loss: 1.1839 - accuracy: 0.5673
# Epoch 46: val_loss improved from 1.52581 to 1.50163, saving model to best_model.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 1.1881 - accuracy: 0.5547 - val_loss: 1.5016 - val_accuracy: 0.3927
# Epoch 47/100
# 16/16 [==============================] - ETA: 0s - loss: 1.1842 - accuracy: 0.5425
# Epoch 47: val_loss did not improve from 1.50163
# 16/16 [==============================] - 1s 33ms/step - loss: 1.1842 - accuracy: 0.5425 - val_loss: 1.5150 - val_accuracy: 0.3927
# Epoch 48/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.1746 - accuracy: 0.5667
# Epoch 48: val_loss did not improve from 1.50163
# 16/16 [==============================] - 0s 24ms/step - loss: 1.1832 - accuracy: 0.5628 - val_loss: 1.5782 - val_accuracy: 0.3563
# Epoch 49/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.2852 - accuracy: 0.5000
# Epoch 49: val_loss did not improve from 1.50163
# 16/16 [==============================] - 0s 19ms/step - loss: 1.2414 - accuracy: 0.5020 - val_loss: 1.5151 - val_accuracy: 0.3806
# Epoch 50/100
# 12/16 [=====================>........] - ETA: 0s - loss: 1.1751 - accuracy: 0.5781
# Epoch 50: val_loss did not improve from 1.50163
# 16/16 [==============================] - 0s 17ms/step - loss: 1.1779 - accuracy: 0.5789 - val_loss: 1.5159 - val_accuracy: 0.3887
# Epoch 51/100
# 13/16 [=======================>......] - ETA: 0s - loss: 1.1568 - accuracy: 0.5721
# Epoch 51: val_loss did not improve from 1.50163
# 16/16 [==============================] - 0s 16ms/step - loss: 1.1533 - accuracy: 0.5709 - val_loss: 1.5127 - val_accuracy: 0.3968
# 8/8 [==============================] - 0s 6ms/step - loss: 1.5016 - accuracy: 0.3927
# Test Loss: 1.5016, Test Accuracy: 0.3927

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(X_te)


y_pred_classes = np.argmax(predictions, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# 정확도 계산
accuracy = accuracy_score(y_true_classes, y_pred_classes)

# 정밀도 계산
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')

# 재현율 계산
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')

# F1 스코어 계산
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.39271255060728744
# Precision: 0.3723986147467929
# Recall: 0.39271255060728744
# F1 score: 0.3772380657615063
# c:\anaconda3\envs\py_397\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # 간소화된 등급 예측

# %%
y_test = df_new.iloc[:, [-1]]
y_test
# Out:
#     23_08_등급
# 0          E
# 1         B+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       C0
# 245       B0
# 246       B0
#
# [247 rows x 1 columns]

# %%
X_test = pd.concat((df_new.iloc[:, -108:-100], df_new.iloc[:, -99:-91], df_new.iloc[:, -90:-82], df_new.iloc[:, -81:-73], df_new.iloc[:, -72:-64], df_new.iloc[:, -63:-55], df_new.iloc[:, -54:-46], df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19], df_new.iloc[:, -18:-10]), axis=1)
X_test
# Out:
#     22_09_구독자점수 22_09_조회수점수 22_09_충성도점수 22_09_구독자 성장율점수 22_09_감성점수점수  \
# 0           0.0           0           0             5.0            0
# 1          3.75           9           2             7.5            6
# 2           7.5           3           6             7.5            2
# 3          3.75           6           8             7.5            8
# 4          15.0           0           0             5.0            0
# ..          ...         ...         ...             ...          ...
# 242        15.0          15           4             5.0            6
# 243        15.0          15           4             5.0            6
# 244         0.0           0           0             5.0            0
# 245         7.5           6           8             0.0            6
# 246        15.0          15           6             7.5            4
#
#     22_09_평균_영상간격점수 22_09_평균 영상 좋아요 수 점수 22_09_영상개수 점수 22_10_구독자점수  \
# 0                 0                    0             0         0.0
# 1                 0                    4             3        3.75
# 2                 6                    4             6         7.5
# 3                12                    4             9        3.75
# 4                 0                    0             0        15.0
# ..              ...                  ...           ...         ...
# 242              15                   10             9        15.0
# 243              12                   10             9        15.0
# 244               0                    0             0         0.0
# 245              15                    2             9         7.5
# 246               6                   10             6        15.0
#
#     22_10_조회수점수  ... 23_06_평균 영상 좋아요 수 점수 23_06_영상개수 점수 23_07_구독자점수  \
# 0             0  ...                    0             0         0.0
# 1             0  ...                    6             9         7.5
# 2             3  ...                    2             3         7.5
# 3             9  ...                    0             0        3.75
# 4             9  ...                    4             9        15.0
# ..          ...  ...                  ...           ...         ...
# 242          15  ...                   10             9        15.0
# 243          15  ...                   10             9        15.0
# 244           9  ...                    2             3         0.0
# 245           3  ...                    2             6         7.5
# 246          15  ...                   10             9        15.0
#
#     23_07_조회수점수 23_07_충성도점수 23_07_구독자 성장율점수 23_07_감성점수점수 23_07_평균_영상간격점수  \
# 0             0           0             5.0            0               0
# 1             6           6             7.5            2               6
# 2             3           2             7.5            2               0
# 3             9           2             7.5            2               0
# 4             9           8             0.0            4               9
# ..          ...         ...             ...          ...             ...
# 242          15           4             5.0            4              12
# 243          15           6             7.5            8               6
# 244          12           2             7.5            2               0
# 245           3           8             5.0            8               6
# 246          15           6             7.5            6               9
#
#     23_07_평균 영상 좋아요 수 점수 23_07_영상개수 점수
# 0                      0             0
# 1                      4             3
# 2                      4             3
# 3                      6             3
# 4                      4             9
# ..                   ...           ...
# 242                   10             9
# 243                   10             9
# 244                    2             3
# 245                    2             6
# 246                   10             9
#
# [247 rows x 88 columns]

# %%
y_train = df_new.iloc[:, [-10]]
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
X_train = pd.concat((df_new.iloc[:, -117:-109], df_new.iloc[:, -108:-100], df_new.iloc[:, -99:-91], df_new.iloc[:, -90:-82], df_new.iloc[:, -81:-73], df_new.iloc[:, -72:-64], df_new.iloc[:, -63:-55], df_new.iloc[:, -54:-46], df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19]), axis=1)
X_train
# Out:
#     22_08_구독자점수 22_08_조회수점수 22_08_충성도점수 22_08_구독자 성장율점수 22_08_감성점수점수  \
# 0           0.0           0           0             7.5            0
# 1          3.75           6           8             7.5            2
# 2           7.5           3           2             7.5            4
# 3          3.75           0           0             7.5            0
# 4          15.0           0           0             0.0            0
# ..          ...         ...         ...             ...          ...
# 242        15.0          15           4             5.0            8
# 243        15.0          15           4             5.0            6
# 244         0.0          15           2             0.0            2
# 245         7.5           3           2             0.0            8
# 246        15.0          15           2             7.5            6
#
#     22_08_평균_영상간격점수 22_08_평균 영상 좋아요 수 점수 22_08_영상개수 점수 22_09_구독자점수  \
# 0                 0                    0             0         0.0
# 1                 6                    4             6        3.75
# 2                 3                    4             3         7.5
# 3                 0                    0             0        3.75
# 4                 0                    0             0        15.0
# ..              ...                  ...           ...         ...
# 242              12                   10             9        15.0
# 243              15                   10            12        15.0
# 244               0                    4             3         0.0
# 245               3                    2             3         7.5
# 246               6                   10             3        15.0
#
#     22_09_조회수점수  ... 23_05_평균 영상 좋아요 수 점수 23_05_영상개수 점수 23_06_구독자점수  \
# 0             0  ...                    2             3         0.0
# 1             9  ...                    6             3        3.75
# 2             3  ...                    4             6         7.5
# 3             6  ...                    4             6        3.75
# 4             0  ...                    4             9        15.0
# ..          ...  ...                  ...           ...         ...
# 242          15  ...                   10             9        15.0
# 243          15  ...                   10             9        15.0
# 244           0  ...                    0             0         0.0
# 245           6  ...                    2             9         7.5
# 246          15  ...                   10             6        15.0
#
#     23_06_조회수점수 23_06_충성도점수 23_06_구독자 성장율점수 23_06_감성점수점수 23_06_평균_영상간격점수  \
# 0             0           0             0.0            0               0
# 1            12           6             7.5            2               6
# 2             3           2             7.5           10               0
# 3             0           0             7.5            0               0
# 4             6           8             5.0            6               9
# ..          ...         ...             ...          ...             ...
# 242          15           4             5.0            6              15
# 243          15           6             7.5            6              12
# 244           3           2             0.0            2               0
# 245           3           6             5.0            6               3
# 246          15           8             7.5            4               9
#
#     23_06_평균 영상 좋아요 수 점수 23_06_영상개수 점수
# 0                      0             0
# 1                      6             9
# 2                      2             3
# 3                      0             0
# 4                      4             9
# ..                   ...           ...
# 242                   10             9
# 243                   10             9
# 244                    2             3
# 245                    2             6
# 246                   10             9
#
# [247 rows x 88 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_train)
scaled_features = pd.DataFrame(scaled_features, columns = X_train.columns)
# 데이터 변환

X_tr= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_train.columns[:8].str.replace('15년_', ''))
    for j in range(11):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_tr.append(temp_df.values)

X_tr= np.array(X_tr)
y_tr = np.array(y_train.values)
X_tr.shape, y_tr.shape
# Out:
# ((247, 11, 8), (247, 1))

# %%
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_test)
scaled_features = pd.DataFrame(scaled_features, columns = X_test.columns)
# 데이터 변환

X_te= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_test.columns[:8].str.replace('15년_', ''))
    for j in range(11):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_te.append(temp_df.values)

X_te= np.array(X_te)
y_te = np.array(y_test.values)
X_te.shape, y_te.shape
# Out:
# ((247, 11, 8), (247, 1))

# %%
def label_encode_dataframe_2(df, column_name):
    label_mapping = {
        'A+': 0, 'A0': 0, 'B+': 1, 'B0': 1,
        'C+': 2, 'C0': 2, 'D+': 3, 'D0': 3,
        'E': 4, 'F': 4
    }
    df[column_name] = df[column_name].map(label_mapping)
    return df

# %%
label_encode_dataframe_2(y_train, y_train.columns[0])
label_encode_dataframe_2(y_test, y_test.columns[0])
# Out:
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\3906280974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\3906280974.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
#      23_08_등급
# 0           4
# 1           1
# 2           3
# 3           2
# 4           1
# ..        ...
# 242         0
# 243         0
# 244         2
# 245         1
# 246         1
#
# [247 rows x 1 columns]

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# 시계열 데이터 생성 (예제 데이터)
# X: 시계열 특성 데이터, y: 다중 클래스 레이블
# 이 예제에서는 임의의 데이터를 생성합니다. 실제 데이터에 대한 적용을 위해 데이터를 준비해야 합니다.

X_tr = tf.convert_to_tensor(X_tr, dtype=tf.float32)
X_te = tf.convert_to_tensor(X_te, dtype=tf.float32)

# LSTM 모델 생성
model = Sequential()
# model.add(LSTM(units=128, input_shape=(11, 8), return_sequences=True))
model.add(LSTM(units=64,  input_shape=(11, 8)))
model.add(Dense(units=5, activation='softmax'))

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 저장 콜백 설정
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, save_weights_only=False, monitor='val_loss', mode='min', verbose=1)

# 모델 학습
history = model.fit(X_tr, y_train, epochs=100, batch_size=16, validation_data=(X_te, y_test), callbacks=[early_stopping, model_checkpoint])

# 모델 평가
loss, accuracy = model.evaluate(X_te, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100
# 10/16 [=================>............] - ETA: 0s - loss: 1.4518 - accuracy: 0.3562
# Epoch 1: val_loss improved from inf to 1.34112, saving model to best_model.h5
# 16/16 [==============================] - 5s 87ms/step - loss: 1.4326 - accuracy: 0.3684 - val_loss: 1.3411 - val_accuracy: 0.3968
# Epoch 2/100
# 15/16 [===========================>..] - ETA: 0s - loss: 1.2686 - accuracy: 0.4833
# Epoch 2: val_loss improved from 1.34112 to 1.23895, saving model to best_model.h5
# 16/16 [==============================] - 0s 25ms/step - loss: 1.2756 - accuracy: 0.4777 - val_loss: 1.2390 - val_accuracy: 0.4413
# Epoch 3/100
#  9/16 [===============>..............] - ETA: 0s - loss: 1.2196 - accuracy: 0.4861
# Epoch 3: val_loss improved from 1.23895 to 1.16073, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 1.1563 - accuracy: 0.5223 - val_loss: 1.1607 - val_accuracy: 0.4453
# Epoch 4/100
# 14/16 [=========================>....] - ETA: 0s - loss: 1.0405 - accuracy: 0.5179
# Epoch 4: val_loss improved from 1.16073 to 1.11471, saving model to best_model.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0598 - accuracy: 0.4939 - val_loss: 1.1147 - val_accuracy: 0.4453
# Epoch 5/100
# 13/16 [=======================>......] - ETA: 0s - loss: 1.0255 - accuracy: 0.5096
# Epoch 5: val_loss improved from 1.11471 to 1.05111, saving model to best_model.h5
# 16/16 [==============================] - 0s 18ms/step - loss: 1.0148 - accuracy: 0.5263 - val_loss: 1.0511 - val_accuracy: 0.4575
# Epoch 6/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.9807 - accuracy: 0.5491
# Epoch 6: val_loss improved from 1.05111 to 1.00635, saving model to best_model.h5
# 16/16 [==============================] - 0s 16ms/step - loss: 0.9851 - accuracy: 0.5304 - val_loss: 1.0063 - val_accuracy: 0.4818
# Epoch 7/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9608 - accuracy: 0.5583
# Epoch 7: val_loss improved from 1.00635 to 0.97338, saving model to best_model.h5
# 16/16 [==============================] - 0s 16ms/step - loss: 0.9550 - accuracy: 0.5628 - val_loss: 0.9734 - val_accuracy: 0.5182
# Epoch 8/100
#  9/16 [===============>..............] - ETA: 0s - loss: 0.9167 - accuracy: 0.5694
# Epoch 8: val_loss did not improve from 0.97338
# 16/16 [==============================] - 0s 12ms/step - loss: 0.9323 - accuracy: 0.5587 - val_loss: 0.9898 - val_accuracy: 0.4656
# Epoch 9/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.9367 - accuracy: 0.5580
# Epoch 9: val_loss improved from 0.97338 to 0.96066, saving model to best_model.h5
# 16/16 [==============================] - 0s 17ms/step - loss: 0.9307 - accuracy: 0.5587 - val_loss: 0.9607 - val_accuracy: 0.5020
# Epoch 10/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.9344 - accuracy: 0.5750
# Epoch 10: val_loss did not improve from 0.96066
# 16/16 [==============================] - 0s 9ms/step - loss: 0.9156 - accuracy: 0.5870 - val_loss: 0.9616 - val_accuracy: 0.5182
# Epoch 11/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.9284 - accuracy: 0.5917
# Epoch 11: val_loss improved from 0.96066 to 0.94782, saving model to best_model.h5
# 16/16 [==============================] - 0s 16ms/step - loss: 0.9234 - accuracy: 0.5911 - val_loss: 0.9478 - val_accuracy: 0.5263
# Epoch 12/100
#  9/16 [===============>..............] - ETA: 0s - loss: 0.8680 - accuracy: 0.6042
# Epoch 12: val_loss did not improve from 0.94782
# 16/16 [==============================] - 0s 10ms/step - loss: 0.8817 - accuracy: 0.6113 - val_loss: 0.9714 - val_accuracy: 0.5304
# Epoch 13/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.8760 - accuracy: 0.6083
# Epoch 13: val_loss improved from 0.94782 to 0.93151, saving model to best_model.h5
# 16/16 [==============================] - 0s 25ms/step - loss:
100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.7749 - accuracy: 0.6429
# Epoch 54: val_loss did not improve from 0.86007
# 16/16 [==============================] - 0s 15ms/step - loss: 0.7558 - accuracy: 0.6518 - val_loss: 1.0294 - val_accuracy: 0.5749
# Epoch 55/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7497 - accuracy: 0.6917
# Epoch 55: val_loss did not improve from 0.86007
# 16/16 [==============================] - 0s 24ms/step - loss: 0.7422 - accuracy: 0.6964 - val_loss: 0.8927 - val_accuracy: 0.5992
# Epoch 56/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.7181 - accuracy: 0.6964
# Epoch 56: val_loss did not improve from 0.86007
# 16/16 [==============================] - 0s 21ms/step - loss: 0.7093 - accuracy: 0.7004 - val_loss: 0.8759 - val_accuracy: 0.6113
# 8/8 [==============================] - 0s 4ms/step - loss: 0.8601 - accuracy: 0.5951
# Test Loss: 0.8601, Test Accuracy: 0.5951

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(X_te)


y_pred_classes = np.argmax(predictions, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# 정확도 계산
accuracy = accuracy_score(y_true_classes, y_pred_classes)

# 정밀도 계산
precision = precision_score(y_true_classes, y_pred_classes, average='weighted')

# 재현율 계산
recall = recall_score(y_true_classes, y_pred_classes, average='weighted')

# F1 스코어 계산
f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.5951417004048583
# Precision: 0.6185444900567284
# Recall: 0.5951417004048583
# F1 score: 0.5826227984959915

# %% [markdown]
# # 인기, 비인기 예측

# %%
y_test = df_new.iloc[:, [-1]]
y_test
# Out:
#     23_08_등급
# 0          E
# 1         B+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       C0
# 245       B0
# 246       B0
#
# [247 rows x 1 columns]

# %%
X_test = pd.concat((df_new.iloc[:, -108:-100], df_new.iloc[:, -99:-91], df_new.iloc[:, -90:-82], df_new.iloc[:, -81:-73], df_new.iloc[:, -72:-64], df_new.iloc[:, -63:-55], df_new.iloc[:, -54:-46], df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19], df_new.iloc[:, -18:-10]), axis=1)
X_test
# Out:
#     22_09_구독자점수 22_09_조회수점수 22_09_충성도점수 22_09_구독자 성장율점수 22_09_감성점수점수  \
# 0           0.0           0           0             5.0            0
# 1          3.75           9           2             7.5            6
# 2           7.5           3           6             7.5            2
# 3          3.75           6           8             7.5            8
# 4          15.0           0           0             5.0            0
# ..          ...         ...         ...             ...          ...
# 242        15.0          15           4             5.0            6
# 243        15.0          15           4             5.0            6
# 244         0.0           0           0             5.0            0
# 245         7.5           6           8             0.0            6
# 246        15.0          15           6             7.5            4
#
#     22_09_평균_영상간격점수 22_09_평균 영상 좋아요 수 점수 22_09_영상개수 점수 22_10_구독자점수  \
# 0                 0                    0             0         0.0
# 1                 0                    4             3        3.75
# 2                 6                    4             6         7.5
# 3                12                    4             9        3.75
# 4                 0                    0             0        15.0
# ..              ...                  ...           ...         ...
# 242              15                   10             9        15.0
# 243              12                   10             9        15.0
# 244               0                    0             0         0.0
# 245              15                    2             9         7.5
# 246               6                   10             6        15.0
#
#     22_10_조회수점수  ... 23_06_평균 영상 좋아요 수 점수 23_06_영상개수 점수 23_07_구독자점수  \
# 0             0  ...                    0             0         0.0
# 1             0  ...                    6             9         7.5
# 2             3  ...                    2             3         7.5
# 3             9  ...                    0             0        3.75
# 4             9  ...                    4             9        15.0
# ..          ...  ...                  ...           ...         ...
# 242          15  ...                   10             9        15.0
# 243          15  ...                   10             9        15.0
# 244           9  ...                    2             3         0.0
# 245           3  ...                    2             6         7.5
# 246          15  ...                   10             9        15.0
#
#     23_07_조회수점수 23_07_충성도점수 23_07_구독자 성장율점수 23_07_감성점수점수 23_07_평균_영상간격점수  \
# 0             0           0             5.0            0               0
# 1             6           6             7.5            2               6
# 2             3           2             7.5            2               0
# 3             9           2             7.5            2               0
# 4             9           8             0.0            4               9
# ..          ...         ...             ...          ...             ...
# 242          15           4             5.0            4              12
# 243          15           6             7.5            8               6
# 244          12           2             7.5            2               0
# 245           3           8             5.0            8               6
# 246          15           6             7.5            6               9
#
#     23_07_평균 영상 좋아요 수 점수 23_07_영상개수 점수
# 0                      0             0
# 1                      4             3
# 2                      4             3
# 3                      6             3
# 4                      4             9
# ..                   ...           ...
# 242                   10             9
# 243                   10             9
# 244                    2             3
# 245                    2             6
# 246                   10             9
#
# [247 rows x 88 columns]

# %%
y_train = df_new.iloc[:, [-10]]
y_train
# Out:
#     23_07_등급
# 0         D0
# 1         C+
# 2         D+
# 3         C0
# 4         B0
# ..       ...
# 242       A0
# 243       A0
# 244       D+
# 245       C+
# 246       A0
#
# [247 rows x 1 columns]

# %%
X_train = pd.concat((df_new.iloc[:, -117:-109], df_new.iloc[:, -108:-100], df_new.iloc[:, -99:-91], df_new.iloc[:, -90:-82], df_new.iloc[:, -81:-73], df_new.iloc[:, -72:-64], df_new.iloc[:, -63:-55], df_new.iloc[:, -54:-46], df_new.iloc[:, -45:-37], df_new.iloc[:, -36:-28], df_new.iloc[:, -27:-19]), axis=1)
X_train
# Out:
#     22_08_구독자점수 22_08_조회수점수 22_08_충성도점수 22_08_구독자 성장율점수 22_08_감성점수점수  \
# 0           0.0           0           0             7.5            0
# 1          3.75           6           8             7.5            2
# 2           7.5           3           2             7.5            4
# 3          3.75           0           0             7.5            0
# 4          15.0           0           0             0.0            0
# ..          ...         ...         ...             ...          ...
# 242        15.0          15           4             5.0            8
# 243        15.0          15           4             5.0            6
# 244         0.0          15           2             0.0            2
# 245         7.5           3           2             0.0            8
# 246        15.0          15           2             7.5            6
#
#     22_08_평균_영상간격점수 22_08_평균 영상 좋아요 수 점수 22_08_영상개수 점수 22_09_구독자점수  \
# 0                 0                    0             0         0.0
# 1                 6                    4             6        3.75
# 2                 3                    4             3         7.5
# 3                 0                    0             0        3.75
# 4                 0                    0             0        15.0
# ..              ...                  ...           ...         ...
# 242              12                   10             9        15.0
# 243              15                   10            12        15.0
# 244               0                    4             3         0.0
# 245               3                    2             3         7.5
# 246               6                   10             3        15.0
#
#     22_09_조회수점수  ... 23_05_평균 영상 좋아요 수 점수 23_05_영상개수 점수 23_06_구독자점수  \
# 0             0  ...                    2             3         0.0
# 1             9  ...                    6             3        3.75
# 2             3  ...                    4             6         7.5
# 3             6  ...                    4             6        3.75
# 4             0  ...                    4             9        15.0
# ..          ...  ...                  ...           ...         ...
# 242          15  ...                   10             9        15.0
# 243          15  ...                   10             9        15.0
# 244           0  ...                    0             0         0.0
# 245           6  ...                    2             9         7.5
# 246          15  ...                   10             6        15.0
#
#     23_06_조회수점수 23_06_충성도점수 23_06_구독자 성장율점수 23_06_감성점수점수 23_06_평균_영상간격점수  \
# 0             0           0             0.0            0               0
# 1            12           6             7.5            2               6
# 2             3           2             7.5           10               0
# 3             0           0             7.5            0               0
# 4             6           8             5.0            6               9
# ..          ...         ...             ...          ...             ...
# 242          15           4             5.0            6              15
# 243          15           6             7.5            6              12
# 244           3           2             0.0            2               0
# 245           3           6             5.0            6               3
# 246          15           8             7.5            4               9
#
#     23_06_평균 영상 좋아요 수 점수 23_06_영상개수 점수
# 0                      0             0
# 1                      6             9
# 2                      2             3
# 3                      0             0
# 4                      4             9
# ..                   ...           ...
# 242                   10             9
# 243                   10             9
# 244                    2             3
# 245                    2             6
# 246                   10             9
#
# [247 rows x 88 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_train)
scaled_features = pd.DataFrame(scaled_features, columns = X_train.columns)
# 데이터 변환

X_tr= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_train.columns[:8].str.replace('15년_', ''))
    for j in range(11):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_tr.append(temp_df.values)

X_tr= np.array(X_tr)
y_tr = np.array(y_train.values)
X_tr.shape, y_tr.shape
# Out:
# ((247, 11, 8), (247, 1))

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(X_test)
scaled_features = pd.DataFrame(scaled_features, columns = X_test.columns)
# 데이터 변환

X_te= []
for i in range(len(scaled_features)):
    temp_df = pd.DataFrame(columns = X_test.columns[:8].str.replace('15년_', ''))
    for j in range(11):
        temp_df.loc[j, :] = scaled_features.iloc[i, j*8:(j+1)*8].values

    X_te.append(temp_df.values)

X_te= np.array(X_te)
y_te = np.array(y_test.values)
X_te.shape, y_te.shape
# Out:
# ((247, 11, 8), (247, 1))

# %%
def label_encode_dataframe_3(df, column_name):
    label_mapping = {
        'A+': 0, 'A0': 0, 'B+': 0, 'B0': 0,
        'C+': 1, 'C0': 1, 'D+': 1, 'D0': 1,
        'E': 1, 'F': 1
    }
    df[column_name] = df[column_name].map(label_mapping)
    return df

# %%
label_encode_dataframe_3(y_train, y_train.columns[0])
label_encode_dataframe_3(y_test, y_test.columns[0])
# Out:
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\2928109579.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
# C:\Users\Mgyu\AppData\Local\Temp\ipykernel_20852\2928109579.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column_name] = df[column_name].map(label_mapping)
#      23_08_등급
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0
# ..        ...
# 242         0
# 243         0
# 244         1
# 245         0
# 246         0
#
# [247 rows x 1 columns]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# 시계열 데이터 생성 (예제 데이터)
# X: 시계열 특성 데이터, y: 다중 클래스 레이블
# 이 예제에서는 임의의 데이터를 생성합니다. 실제 데이터에 대한 적용을 위해 데이터를 준비해야 합니다.

X_tr = tf.convert_to_tensor(X_tr, dtype=tf.float32)
X_te = tf.convert_to_tensor(X_te, dtype=tf.float32)

# LSTM 모델 생성
model = Sequential()
#model.add(LSTM(units=128, input_shape=(11, 8), return_sequences=True))
model.add(LSTM(units=64,  input_shape=(11, 8)))
model.add(Dense(units=1, activation='sigmoid'))

# 모델 컴파일
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 저장 콜백 설정
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, save_weights_only=False, monitor='val_loss', mode='min', verbose=1)

# 모델 학습
history = model.fit(X_tr, y_train, epochs=100, batch_size=16, validation_data=(X_te, y_test), callbacks=[early_stopping, model_checkpoint])

# 모델 평가
loss, accuracy = model.evaluate(X_te, y_test)
print(f'Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2932 - accuracy: 0.8785 - val_loss: 0.3406 - val_accuracy: 0.8300
# Epoch 36/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.2340 - accuracy: 0.9000
# Epoch 36: val_loss did not improve from 0.32917
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2884 - accuracy: 0.8664 - val_loss: 0.3372 - val_accuracy: 0.8381
# Epoch 37/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.3278 - accuracy: 0.8438
# Epoch 37: val_loss improved from 0.32917 to 0.32202, saving model to best_model.h5
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2958 - accuracy: 0.8543 - val_loss: 0.3220 - val_accuracy: 0.8340
# Epoch 38/100
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2792 - accuracy: 0.8667
# Epoch 38: val_loss did not improve from 0.32202
# 16/16 [==============================] - 0s 16ms/step - loss: 0.2961 - accuracy: 0.8623 - val_loss: 0.3398 - val_accuracy: 0.8340
# Epoch 39/100
#  9/16 [===============>..............] - ETA: 0s - loss: 0.2872 - accuracy: 0.8889
# Epoch 39: val_loss did not improve from 0.32202
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2849 - accuracy: 0.8785 - val_loss: 0.3226 - val_accuracy: 0.8340
# Epoch 40/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.2531 - accuracy: 0.8813
# Epoch 40: val_loss did not improve from 0.32202
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2829 - accuracy: 0.8664 - val_loss: 0.3303 - val_accuracy: 0.8381
# Epoch 41/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.2930 - accuracy: 0.8562
# Epoch 41: val_loss did not improve from 0.32202
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2898 - accuracy: 0.8664 - val_loss: 0.3505 - val_accuracy: 0.8502
# Epoch 42/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.2934 - accuracy: 0.8625
# Epoch 42: val_loss improved from 0.32202 to 0.32026, saving model to best_model.h5
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2914 - accuracy: 0.8623 - val_loss: 0.3203 - val_accuracy: 0.8340
# Epoch 43/100
# 14/16 [=========================>....] - ETA: 0s - loss: 0.2926 - accuracy: 0.8661
# Epoch 43: val_loss improved from 0.32026 to 0.32021, saving model to best_model.h5
# 16/16 [==============================] - 0s 15ms/step - loss: 0.2971 - accuracy: 0.8623 - val_loss: 0.3202 - val_accuracy: 0.8340
# Epoch 44/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.3424 - accuracy: 0.8500
# Epoch 44: val_loss did not improve from 0.32021
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3107 - accuracy: 0.8502 - val_loss: 0.3353 - val_accuracy: 0.8421
# Epoch 45/100
# 11/16 [===================>..........] - ETA: 0s - loss: 0.3070 - accuracy: 0.8409
# Epoch 45: val_loss did not improve from 0.32021
# 16/16 [==============================] - 0s 9ms/step - loss: 0.2792 - accuracy: 0.8623 - val_loss: 0.3304 - val_accuracy: 0.8300
# Epoch 46/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.2422 - accuracy: 0.9000
# Epoch 46: val_loss did not improve from 0.32021
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2717 - accuracy: 0.8785 - val_loss: 0.3317 - val_accuracy: 0.8462
# Epoch 47/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.3074 - accuracy: 0.8500
# Epoch 47: val_loss did not improve from 0.32021
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2704 - accuracy: 0.8745 - val_loss: 0.3243 - val_accuracy: 0.8421
# Epoch 48/100
# 10/16 [=================>............] - ETA: 0s - loss: 0.2895 - accuracy: 0.8938
# Epoch 48: val_loss did not improve from 0.32021
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2788 - accuracy: 0.8826 - val_loss: 0.3420 - val_accuracy: 0.8381
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3202 - accuracy: 0.8340
# Test Loss: 0.3202, Test Accuracy: 0.8340

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

predictions = model.predict(X_te)


y_pred = np.round(predictions)

# 정확도 계산
accuracy = accuracy_score(y_test, y_pred)

# 정밀도 계산
precision = precision_score(y_test, y_pred)

# 재현율 계산
recall = recall_score(y_test, y_pred)

# F1 스코어 계산
f1 = f1_score(y_test, y_pred)

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.8340080971659919
# Precision: 0.8823529411764706
# Recall: 0.7954545454545454
# F1 score: 0.8366533864541832
